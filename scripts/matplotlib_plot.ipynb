# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### plt.plot()

# %%
plt.plot([2, 4, 6, 8])
#plt.plot(y) -> (0, y1) (1, y2) (2, y3) ....

# %%
salaries = [55000, 22000, 45500, 40000, 50000]
ages = [20, 25, 30, 32, 45]

plt.plot(ages, salaries)
# plt.plot -> 원래 아무것도 보여주지 않음 (jupyter 기능)
# 원래는 plt.show() 해야함

# %% [markdown]
# ### figure

# %%
import numpy as np
nums = np.arange(5)

# %%
plt.plot(nums, nums)
plt.plot(nums, nums*nums)
plt.plot(nums, nums**3)

# %% [markdown]
# ##### figure : axes를 그릴 수 있는 캔버스 (axes가 여러 개 들어갈 수도 있음)
# ##### axes : 개별 플롯

# %%
plt.figure() # 새 figure -> 이후 추가 되는 모든 axes는 이 figure에 추가됨
plt.plot(nums, nums)
plt.figure()
plt.plot(nums, nums*nums)
plt.figure()
plt.plot(nums, nums**3)

# %% [markdown]
# ### size of figure

# %%
plt.figure(figsize=(10, 10))
# figsize -> figure의 크기 인치 단위
plt.plot()
# Out:
# []

# %% [markdown]
# ### style

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
plt.plot(nums, nums)
plt.plot(nums, nums*nums)
plt.plot(nums, nums**3)

# %%
plt.style.use('seaborn')

# %%
# plt.plot의 가변인자로 스타일 정보를 전달할 수 있다.
plt.plot(nums, nums**3, linestyle="dotted", marker="*", markersize=10, markerfacecolor='pink')

# %% [markdown]
# ### title, label

# %%
salaries = [55000, 22000, 45500, 40000, 50000]
ages = [20, 25, 30, 32, 45]

plt.plot(ages, salaries)
plt.title('Company salaries')
plt.xlabel("Age", labelpad=10)
plt.ylabel("salaries", labelpad= 30, rotation="horizontal")
# Out:
# Text(0, 0.5, 'salaries')

# %%
salaries = [55000, 22000, 45500, 40000, 50000]
ages = [20, 25, 30, 32, 45]

plt.plot(ages, salaries)
plt.title('Company salaries')

plt.xlabel("Age", labelpad=10)
plt.ylabel("salaries", labelpad= 30, rotation="horizontal")

plt.xticks([20, 25, 30, 32, 45], labels=['A', 'B', 'C', 'D', 'E'])

plt.xlim(20, 45)
# Out:
# (20.0, 45.0)

# %% [markdown]
# ### 범례 추가

# %%
plt.figure(figsize=(8, 8))
plt.plot(nums, color="teal", label="linear")
plt.plot(nums**2, color="olive", label="squared")
plt.plot(nums**3, color="violet", label="cubed")

plt.legend(loc='center left')

# %% [markdown]
# ### barplot

# %%
plants = ['Spinach', 'Turnip', 'Rhubarb', 'Broccoli', 'Kale']
died = [10, 25, 5, 30, 21]
germinated = [74, 88, 56, 69, 59]

# %%
plt.figure(figsize=(6, 6))
plt.bar(x=plants, height=germinated, width=0.5, color="seagreen")
plt.title("Germination Rate")
plt.ylabel("Number of Seedlings")
# Out:
# Text(0, 0.5, 'Number of Seedlings')

# %%
plt.figure(figsize=(6, 6))
plt.bar(plants, died, width=0.5, color="red")
plt.title("Failure Rate")
plt.ylabel("Number of Seedlings")
# Out:
# Text(0, 0.5, 'Number of Seedlings')

# %%
plt.figure(figsize=(6, 6))
plt.bar(x=plants, height=germinated, width=-0.3, color="seagreen", align='edge')
plt.bar(plants, died, width=0.3, color="red", align='edge')
plt.title("Germination Rate")
plt.ylabel("Number of Seedlings")
# Out:
# Text(0, 0.5, 'Number of Seedlings')

# %% [markdown]
# ### histogram

# %%
num_n = np.random.randn(100)
plt.hist(num_n)
# Out:
# (array([ 1.,  1.,  5., 21., 20., 23., 21.,  5.,  2.,  1.]),
#  array([-3.27550655, -2.63869486, -2.00188317, -1.36507149, -0.7282598 ,
#         -0.09144811,  0.54536358,  1.18217526,  1.81898695,  2.45579864,
#          3.09261033]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(num_n, bins = 20)
# Out:
# (array([ 1.,  0.,  0.,  1.,  3.,  2.,  6., 15.,  7., 13., 15.,  8., 14.,
#          7.,  4.,  1.,  1.,  1.,  0.,  1.]),
#  array([-3.27550655, -2.9571007 , -2.63869486, -2.32028902, -2.00188317,
#         -1.68347733, -1.36507149, -1.04666564, -0.7282598 , -0.40985395,
#         -0.09144811,  0.22695773,  0.54536358,  0.86376942,  1.18217526,
#          1.50058111,  1.81898695,  2.1373928 ,  2.45579864,  2.77420448,
#          3.09261033]),
#  <BarContainer object of 20 artists>)
