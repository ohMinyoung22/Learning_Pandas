# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### plt.plot()

# %%
plt.plot([2, 4, 6, 8])
#plt.plot(y) -> (0, y1) (1, y2) (2, y3) ....

# %%
salaries = [55000, 22000, 45500, 40000, 50000]
ages = [20, 25, 30, 32, 45]

plt.plot(ages, salaries)
# plt.plot -> 원래 아무것도 보여주지 않음 (jupyter 기능)
# 원래는 plt.show() 해야함

# %% [markdown]
# ### figure

# %%
import numpy as np
nums = np.arange(5)

# %%
plt.plot(nums, nums)
plt.plot(nums, nums*nums)
plt.plot(nums, nums**3)

# %% [markdown]
# ##### figure : axes를 그릴 수 있는 캔버스 (axes가 여러 개 들어갈 수도 있음)
# ##### axes : 개별 플롯

# %%
plt.figure() # 새 figure -> 이후 추가 되는 모든 axes는 이 figure에 추가됨
plt.plot(nums, nums)
plt.figure()
plt.plot(nums, nums*nums)
plt.figure()
plt.plot(nums, nums**3)

# %% [markdown]
# ### size of figure

# %%
plt.figure(figsize=(10, 10))
# figsize -> figure의 크기 인치 단위
plt.plot()
# Out:
# []

# %% [markdown]
# ### style

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
plt.plot(nums, nums)
plt.plot(nums, nums*nums)
plt.plot(nums, nums**3)

# %%
plt.style.use('seaborn')

# %%
# plt.plot의 가변인자로 스타일 정보를 전달할 수 있다.
plt.plot(nums, nums**3, linestyle="dotted", marker="*", markersize=10, markerfacecolor='pink')

# %% [markdown]
# ### title, label

# %%
salaries = [55000, 22000, 45500, 40000, 50000]
ages = [20, 25, 30, 32, 45]

plt.plot(ages, salaries)
plt.title('Company salaries')
plt.xlabel("Age", labelpad=10)
plt.ylabel("salaries", labelpad= 30, rotation="horizontal")
# Out:
# Text(0, 0.5, 'salaries')

# %%
salaries = [55000, 22000, 45500, 40000, 50000]
ages = [20, 25, 30, 32, 45]

plt.plot(ages, salaries)
plt.title('Company salaries')

plt.xlabel("Age", labelpad=10)
plt.ylabel("salaries", labelpad= 30, rotation="horizontal")

plt.xticks([20, 25, 30, 32, 45], labels=['A', 'B', 'C', 'D', 'E'])

plt.xlim(20, 45)
# Out:
# (20.0, 45.0)

# %% [markdown]
# ### 범례 추가

# %%
plt.figure(figsize=(8, 8))
plt.plot(nums, color="teal", label="linear")
plt.plot(nums**2, color="olive", label="squared")
plt.plot(nums**3, color="violet", label="cubed")

plt.legend(loc='center left')

# %% [markdown]
# ### barplot

# %%
plants = ['Spinach', 'Turnip', 'Rhubarb', 'Broccoli', 'Kale']
died = [10, 25, 5, 30, 21]
germinated = [74, 88, 56, 69, 59]

# %%
plt.figure(figsize=(6, 6))
plt.bar(x=plants, height=germinated, width=0.5, color="seagreen")
plt.title("Germination Rate")
plt.ylabel("Number of Seedlings")
# Out:
# Text(0, 0.5, 'Number of Seedlings')

# %%
plt.figure(figsize=(6, 6))
plt.bar(plants, died, width=0.5, color="red")
plt.title("Failure Rate")
plt.ylabel("Number of Seedlings")
# Out:
# Text(0, 0.5, 'Number of Seedlings')

# %%
plt.figure(figsize=(6, 6))
plt.bar(x=plants, height=germinated, width=-0.3, color="seagreen", align='edge')
plt.bar(plants, died, width=0.3, color="red", align='edge')
plt.title("Germination Rate")
plt.ylabel("Number of Seedlings")
# Out:
# Text(0, 0.5, 'Number of Seedlings')

# %% [markdown]
# ### histogram

# %%
num_n = np.random.randn(100)
plt.hist(num_n)
# Out:
# (array([ 7., 18., 15., 26., 14., 10.,  9.,  0.,  0.,  1.]),
#  array([-1.91307146, -1.36109417, -0.80911688, -0.25713959,  0.29483769,
#          0.84681498,  1.39879227,  1.95076956,  2.50274685,  3.05472413,
#          3.60670142]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(num_n, bins = 20)
# Out:
# (array([ 3.,  4., 10.,  8.,  4., 11., 16., 10.,  6.,  8.,  5.,  5.,  8.,
#          1.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([-1.91307146, -1.63708281, -1.36109417, -1.08510553, -0.80911688,
#         -0.53312824, -0.25713959,  0.01884905,  0.29483769,  0.57082634,
#          0.84681498,  1.12280363,  1.39879227,  1.67478091,  1.95076956,
#          2.2267582 ,  2.50274685,  2.77873549,  3.05472413,  3.33071278,
#          3.60670142]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ### Scatterplot

# %%
height = [137, 140, 142, 183]
age = [20, 40, 50, 10]

# %%
plt.scatter(height, age, c='purple', marker='*')

# %%
labels = ['Turkey', 'Potatoes', 'Pumpkin Pie', 'Stuffing']
prices = [25.99, 3.24, 9.5, 6.99]

# %%
plt.pie(prices, labels=labels, autopct="%1.1f%%", explode= (0, 0, 0.1, 0))
# Out:
# ([<matplotlib.patches.Wedge at 0x1f7fa860ca0>,
# ...
#  [Text(-0.23476164907796612, 1.0746566745347996, 'Turkey'),
#   Text(-0.873837836440518, -0.668137287991738, 'Potatoes'),
#   Text(-0.051107835699375104, -1.1989111681563926, 'Pumpkin Pie'),
#   Text(0.9755372148905609, -0.5082589323991933, 'Stuffing')],
#  [Text(-0.1280518085879815, 0.5861763679280724, '56.8%'),
#   Text(-0.47663881987664614, -0.3644385207227661, '7.1%'),
#   Text(-0.029812904157968806, -0.6993648480912289, '20.8%'),
#   Text(0.5321112081221241, -0.2772321449450145, '15.3%')])

# %% [markdown]
# ### Multiple Axes in one figure

# %%
import numpy as np
nums = np.arange(5)

# %%
plt.figure(figsize=(10, 4))
plt.suptitle("Fig")

plt.subplot(1, 3, 1)
plt.title("X")
plt.plot(nums, nums)

plt.subplot(1, 3, 2)
plt.title("Y")
plt.plot(nums, nums**2)

plt.subplot(1, 3, 3)
plt.title("Z")
plt.plot(nums, nums**5)

plt.tight_layout()
