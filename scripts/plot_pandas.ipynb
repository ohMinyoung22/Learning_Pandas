# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("../data/titanic.csv")
titanic["age"] = pd.to_numeric(titanic["age"], errors="coerce")

# %%
houses = pd.read_csv("../data/kc_house_data.csv")

# %%
ufos = pd.read_csv("../data/nuforc_reports.csv", parse_dates=['date_time', "posted"])

# %%
titanic.sex.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
houses[['sqft_living', 'sqft_lot']].sort_values("sqft_living", ascending=False).head(10)
# Out:
#        sqft_living  sqft_lot
# 12777        13540    307752
# 7252         12050     27600
# 3914         10040     37325
# 9254          9890     31374
# 8092          9640     13068
# 4411          9200     35069
# 14556         8670     64033
# 18302         8020     21738
# 1164          8010     45517
# 1448          8000     23985

# %%
houses[['sqft_living', 'sqft_lot']].sort_values("sqft_living", ascending=False).head(10).plot(kind='bar', stacked=True)
plt.title("sqft of houses")
# Out:
# Text(0.5, 1.0, 'sqft of houses')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-pastel")

# %%
titanic.sex.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
ufos["month"] = ufos["date_time"].dt.month

# %%
sightings = ufos.month.value_counts().sort_index()

# %%
ufos.month.value_counts().sort_index().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sightings.rename({1 : "Jan", 2 : "Feb", 3 : "Mar", 4 : "Apr", 5 : "May",
6 : "Jun", 7 : "Jul", 8 : "Aug", 9 : "Seb", 10 : "Oct", 11 : "Nov", 12 : "Dec"}, inplace=True)

# %%
sightings.plot(kind="bar")
# Out:
# <AxesSubplot:>
